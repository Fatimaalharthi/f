# %% [markdown]
# <a href="https://colab.research.google.com/github/Fatimaalharthi/f/blob/main/Stc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyxlsb
# Out:
# Collecting pyxlsb
#   Downloading pyxlsb-1.0.10-py2.py3-none-any.whl (23 kB)
# Installing collected packages: pyxlsb
# Successfully installed pyxlsb-1.0.10

# %%
import pandas as pd
import pyxlsb
import numpy as np

# %%
dataframe = pd.read_excel("/stc TV Data Set_T1.xlsb",sheet_name="Final_Dataset")

# %%
dataframe.shape
# Out:
# (1048575, 13)

# %%
dataframe.head()
# Out:
#    Column1  date_  user_id_maped           program_name  duration_seconds  \
# 0        1  42882          26138             100 treets                40
# 1        3  42876           7946                 Moana                 17
# 2        4  42957           7418  The Mermaid Princess                  8
# 3        5  42942          19307  The Mermaid Princess                 76
# 4        7  42923          15860             Churchill                 87
#
#   program_class  season  episode                              program_desc  \
# 0         MOVIE       0        0                    Drama Movie100 Streets
# 1         MOVIE       0        0                 Animation MovieMoana (HD)
# 2         MOVIE       0        0  Animation MovieThe Mermaid Princess (HD)
# 3         MOVIE       0        0  Animation MovieThe Mermaid Princess (HD)
# 4         MOVIE       0        0             Biography MovieChurchill (HD)
#
#   program_genre  series_title  hd         original_name
# 0         Drama             0   0            100 treets
# 1     Animation             0   1                 Moana
# 2     Animation             0   1  The Mermaid Princess
# 3     Animation             0   1  The Mermaid Princess
# 4     Biography             0   1             Churchill

# %%
dataframe = dataframe.drop(columns=['Column1'])
dataframe['program_name'] = dataframe['program_name'].str.strip()
dataframe['date_'] = pd.to_datetime(dataframe['date_'], unit='d', origin='30/12/1899')
dataframe[['duration_seconds', 'season','episode','series_title','hd']] = dataframe[['duration_seconds', 'season','episode','series_title','hd']].apply(pd.to_numeric)
dataframe[['user_id_maped', 'program_name','program_class','program_desc','program_genre','original_name']] = dataframe[['user_id_maped', 'program_name','program_class','program_desc','program_genre','original_name']].astype(str)
# Out:
# <ipython-input-22-63fc699665ef>:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   dataframe['date_'] = pd.to_datetime(dataframe['date_'], unit='d', origin='30/12/1899')  # read date column as date data type

# %%
dataframe.head()
# Out:
#        date_ user_id_maped          program_name  duration_seconds  \
# 0 2017-05-27         26138            100 treets                40
# 1 2017-05-21          7946                 Moana                17
# 2 2017-08-10          7418  The Mermaid Princess                 8
# 3 2017-07-26         19307  The Mermaid Princess                76
# 4 2017-07-07         15860             Churchill                87
#
#   program_class  season  episode                              program_desc  \
# 0         MOVIE       0        0                    Drama Movie100 Streets
# 1         MOVIE       0        0                 Animation MovieMoana (HD)
# 2         MOVIE       0        0  Animation MovieThe Mermaid Princess (HD)
# 3         MOVIE       0        0  Animation MovieThe Mermaid Princess (HD)
# 4         MOVIE       0        0             Biography MovieChurchill (HD)
#
#   program_genre  series_title  hd         original_name
# 0         Drama             0   0            100 treets
# 1     Animation             0   1                 Moana
# 2     Animation             0   1  The Mermaid Princess
# 3     Animation             0   1  The Mermaid Princess
# 4     Biography             0   1             Churchill
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['duration_seconds'].plot(kind='hist', bins=20, title='duration_seconds')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['hd'].plot(kind='hist', bins=20, title='hd')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_14.groupby('user_id_maped').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_15.groupby('program_name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_16.groupby('program_desc').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_17.groupby('program_genre').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_18.plot(kind='scatter', x='duration_seconds', y='hd', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date_']
#   ys = series['duration_seconds']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_19.sort_values('date_', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('user_id_maped')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='user_id_maped', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date_')
# _ = plt.ylabel('duration_seconds')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date_']
#   ys = series['duration_seconds']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_20.sort_values('date_', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('program_name')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='program_name', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date_')
# _ = plt.ylabel('duration_seconds')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date_']
#   ys = series['duration_seconds']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_21.sort_values('date_', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('program_desc')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='program_desc', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date_')
# _ = plt.ylabel('duration_seconds')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date_']
#   ys = series['duration_seconds']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_22.sort_values('date_', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('program_genre')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='program_genre', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date_')
# _ = plt.ylabel('duration_seconds')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_23['duration_seconds'].plot(kind='line', figsize=(8, 4), title='duration_seconds')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24['hd'].plot(kind='line', figsize=(8, 4), title='hd')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['program_name'].value_counts()
#     for x_label, grp in _df_25.groupby('user_id_maped')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('user_id_maped')
# _ = plt.ylabel('program_name')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['program_desc'].value_counts()
#     for x_label, grp in _df_26.groupby('program_name')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('program_name')
# _ = plt.ylabel('program_desc')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['program_genre'].value_counts()
#     for x_label, grp in _df_27.groupby('program_desc')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('program_desc')
# _ = plt.ylabel('program_genre')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['original_name'].value_counts()
#     for x_label, grp in _df_28.groupby('program_genre')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('program_genre')
# _ = plt.ylabel('original_name')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_29['user_id_maped'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_29, x='duration_seconds', y='user_id_maped', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_30['program_name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_30, x='duration_seconds', y='program_name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_31['program_desc'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_31, x='duration_seconds', y='program_desc', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_32['program_genre'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_32, x='duration_seconds', y='program_genre', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
dataframe.describe()
# Out:
#        duration_seconds        season       episode  series_title  \
# count      1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean       1.230957e+03  1.342139e+00  6.157952e+00  1.205922e-02
# std        6.821058e+03  2.104095e+00  1.222015e+01  1.091504e-01
# min        2.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        5.200000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 50%        1.190000e+02  1.000000e+00  1.000000e+00  0.000000e+00
# 75%        1.328000e+03  1.000000e+00  9.000000e+00  0.000000e+00
# max        1.461329e+06  2.300000e+01  2.820000e+02  1.000000e+00
#
#                  hd
# count  1.048575e+06
# mean   3.862728e-01
# std    4.868946e-01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    1.000000e+00
# max    1.000000e+00
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['duration_seconds'].plot(kind='hist', bins=20, title='duration_seconds')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['season'].plot(kind='hist', bins=20, title='season')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['episode'].plot(kind='hist', bins=20, title='episode')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['series_title'].plot(kind='hist', bins=20, title='series_title')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='duration_seconds', y='season', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='season', y='episode', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='episode', y='series_title', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='series_title', y='hd', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['duration_seconds'].plot(kind='line', figsize=(8, 4), title='duration_seconds')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['season'].plot(kind='line', figsize=(8, 4), title='season')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['episode'].plot(kind='line', figsize=(8, 4), title='episode')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['series_title'].plot(kind='line', figsize=(8, 4), title='series_title')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
dataframe.isnull().any()
# Out:
# date_               False
# user_id_maped       False
# program_name        False
# duration_seconds    False
# program_class       False
# season              False
# episode             False
# program_desc        False
# program_genre       False
# series_title        False
# hd                  False
# original_name       False
# dtype: bool

# %%
df=dataframe.copy()

# %%
grouped=df.copy()
grouped.loc[grouped['program_class'] == 'SERIES/EPISODES', 'program_name'] = grouped['program_name']+'_SE'+grouped['season'].astype(str)+'_EP'+grouped['episode'].astype(str)
grouped = grouped.groupby(['program_name','program_class'])\
.agg({'user_id_maped': [('co1', 'nunique'),('co2', 'count')],\
      'duration_seconds': [('co3', 'sum')] }).reset_index()
grouped.columns = ['program_name','program_class','No of Users who Watched', 'No of watches', 'Total watch time in seconds']
grouped['Total watch time in houres']=grouped['Total watch time in seconds']/3600
grouped = grouped.drop(columns=['Total watch time in seconds'])
grouped = grouped.sort_values(by=['Total watch time in houres', 'No of watches','No of Users who Watched'], ascending=False).reset_index(drop=True)

# %%
grouped.head(35)
# Out:
#                                 program_name    program_class  \
# 0                              The Boss Baby            MOVIE
# 1                      The Amazing pider-Man            MOVIE
# 2                            The Expendables            MOVIE
# 3                                      Moana            MOVIE
# 4                                     Trolls            MOVIE
# 5                                       Bean            MOVIE
# 6                                  The murfs            MOVIE
# 7                         Hotel Transylvania            MOVIE
# 8          Cloudy With a Chance of Meatballs            MOVIE
# 9                The Man With The Iron Fists            MOVIE
# 10                                      Salt            MOVIE
# 11                                  Unbroken            MOVIE
# 12                                ParaNorman            MOVIE
# 13                        Youm Maloosh Lazma            MOVIE
# 14                                 Ferdinand            MOVIE
# 15                              White Chicks            MOVIE
# 16                             Jurassic Park            MOVIE
# 17                          The November Man            MOVIE
# 18                              Total Recall            MOVIE
# 19                                Robin Hood            MOVIE
# 20                            Public Enemies            MOVIE
# 21                            Daddy Day Camp            MOVIE
# 22                                  Oblivion            MOVIE
# 23                                     Blitz            MOVIE
# 24            War for the Planet of the Apes            MOVIE
# 25                                Inside Man            MOVIE
# 26                                  Bad Boys            MOVIE
# 27                                    Easy A            MOVIE
# 28                                Battleship            MOVIE
# 29                                  Baywatch            MOVIE
# 30                               Police tory            MOVIE
# 31  Blindspot     Erase Weary Youth_SE1_EP13  SERIES/EPISODES
# 32                                  47 Ronin            MOVIE
# 33                           Alien: Covenant            MOVIE
# 34                      The Mermaid Princess            MOVIE
#
#     No of Users who Watched  No of watches  Total watch time in houres
# 0                      3389          24047                 2961.350833
# 1                      1011           2877                 1966.119167
# 2                       853           2119                 1961.159444
# 3                      2173           8081                 1706.176944
# 4                      2613          13793                 1601.023056
# 5                       949           3617                 1423.955000
# 6                       867           3132                 1342.141111
# 7                       491           1947                 1096.533611
# 8                       683           2076                  948.674722
# 9                       707           2505                  859.626389
# 10                      563           1082                  767.392778
# 11                      625           1429                  763.078333
# 12                      614           1746                  747.065556
# 13                     1131           2278                  718.109722
# 14                     1278           6817                  714.223056
# 15                      307            916                  711.840833
# 16                      504           1192                  693.394444
# 17                      494           1219                  679.492222
# 18                      587           1108                  661.820000
# 19                      588           1209                  643.935000
# 20                      368            716                  634.035000
# 21                      263            647                  625.338333
# 22                      790           1678                  609.391111
# 23                      562           1200                  570.521944
# 24                      879           2028                  567.597778
# 25                      532           1567                  560.386111
# 26                      438            871                  559.277500
# 27                      513            990                  557.068611
# 28                      634           1324                  552.857222
# 29                     2062           7436                  548.995556
# 30                      409            737                  520.077222
# 31                      125            197                  516.015556
# 32                      521           1701                  515.014722
# 33                     1520           4260                  507.180000
# 34                     2182           7525                  503.111111

# %%
import matplotlib.pyplot as plt
import plotly
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
fig = px.pie(grouped.head(10), values='Total watch time in houres', names='program_name',\
             hover_data=['program_class'],title='top 10 programs in total watch time in houres')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4ab2c00f-e0c2-4dfc-a8d9-1cd409489868" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ab2c00f-e0c2-4dfc-a8d9-1cd409489868")) {                    Plotly.newPlot(                        "4ab2c00f-e0c2-4dfc-a8d9-1cd409489868",                        [{"customdata":[["MOVIE"],["MOVIE"],["MOVIE"],["MOVIE"],["MOVIE"],["MOVIE"],["MOVIE"],["MOVIE"],["MOVIE"],["MOVIE"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"program_name=%{label}\u003cbr\u003eTotal watch time in houres=%{value}\u003cbr\u003eprogram_class=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["The Boss Baby","The Amazing pider-Man","The Expendables","Moana","Trolls","Bean","The murfs","Hotel Transylvania","Cloudy With a Chance of Meatballs","The Man With The Iron Fists"],"legendgroup":"","name":"","showlegend":true,"values":[2961.3508333333334,1966.1191666666666,1961.1594444444445,1706.1769444444444,1601.0230555555556,1423.955,1342.141111111111,1096.5336111111112,948.6747222222223,859.6263888888889],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinew ...

# %%
grouped=df.copy()
grouped = grouped.groupby('program_class')\
.agg({'user_id_maped': [('co1', 'nunique'),('co2', 'count')],\
      'duration_seconds': [('co3', 'sum')] }).reset_index()
grouped.columns = ['program_class','No of Users who Watched', 'No of watches', 'Total watch time in seconds']
grouped['Total watch time in houres']=grouped['Total watch time in seconds']/3600
grouped = grouped.drop(columns=['Total watch time in seconds'])
grouped = grouped.sort_values(by=['Total watch time in houres', 'No of watches','No of Users who Watched'], ascending=False).reset_index(drop=True)

# %%
grouped.head()
# Out:
#      program_class  No of Users who Watched  No of watches  \
# 0  SERIES/EPISODES                     3901         560174
# 1            MOVIE                    11355         488401
#
#    Total watch time in houres
# 0               255097.787500
# 1               103444.145556

# %%
fig = px.pie(grouped, values='Total watch time in houres', names='program_class',\
             hover_data=['program_class'],title='Total duration spent by program_class')
fig2 = px.pie(grouped, values='No of Users who Watched', names='program_class',\
             hover_data=['program_class'],title='Total Users watching by program_class')

fig.update_traces(sort=False)
fig2.update_traces(sort=False)
fig.show()
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="68922c53-2b08-4a51-bbe5-f9e694a47ae5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("68922c53-2b08-4a51-bbe5-f9e694a47ae5")) {                    Plotly.newPlot(                        "68922c53-2b08-4a51-bbe5-f9e694a47ae5",                        [{"customdata":[["SERIES\u002fEPISODES"],["MOVIE"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"program_class=%{customdata[0]}\u003cbr\u003eTotal watch time in houres=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["SERIES\u002fEPISODES","MOVIE"],"legendgroup":"","name":"","showlegend":true,"values":[255097.7875,103444.14555555556],"type":"pie","sort":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d6279ebc-f76b-4b76-8032-c27e671e984f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6279ebc-f76b-4b76-8032-c27e671e984f")) {                    Plotly.newPlot(                        "d6279ebc-f76b-4b76-8032-c27e671e984f",                        [{"customdata":[["SERIES\u002fEPISODES"],["MOVIE"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"program_class=%{customdata[0]}\u003cbr\u003eNo of Users who Watched=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["SERIES\u002fEPISODES","MOVIE"],"legendgroup":"","name":"","showlegend":true,"values":[3901,11355],"type":"pie","sort":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatt ...
